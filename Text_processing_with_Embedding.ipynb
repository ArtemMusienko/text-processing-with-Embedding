# %% [markdown]
# ## Решение задачи:
#
# Выполним установку токенизатора **Razdel**, загрузим предобученные **Embedding**.
# И установим большую базу текстов на русском языке - **navec**.

# %%
# !pip install razdel
# !wget https://storage.yandexcloud.net/natasha-navec/packs/navec_hudlit_v1_12B_500K_300d_100q.tar
# !pip install navec
# Out:
# Requirement already satisfied: razdel in /usr/local/lib/python3.11/dist-packages (0.5.0)
# --2025-04-26 16:56:55--  https://storage.yandexcloud.net/natasha-navec/packs/navec_hudlit_v1_12B_500K_300d_100q.tar
# Resolving storage.yandexcloud.net (storage.yandexcloud.net)... 213.180.193.243, 2a02:6b8::1d9
# Connecting to storage.yandexcloud.net (storage.yandexcloud.net)|213.180.193.243|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 53012480 (51M) [application/x-tar]
# Saving to: ‘navec_hudlit_v1_12B_500K_300d_100q.tar.7’
#
# navec_hudlit_v1_12B 100%[===================>]  50.56M  17.4MB/s    in 2.9s
#
# 2025-04-26 16:56:58 (17.4 MB/s) - ‘navec_hudlit_v1_12B_500K_300d_100q.tar.7’ saved [53012480/53012480]
#
# Requirement already satisfied: navec in /usr/local/lib/python3.11/dist-packages (0.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from navec) (2.0.2)

# %% [markdown]
# Установим необходимые библиотеки для дальнейшей работы, а также укажем параметры для "**скользящего окна**".

# %%
from sklearn.model_selection import train_test_split
from navec import Navec
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.models import Sequential, load_model
from keras.layers import Embedding, GlobalAveragePooling1D, Dense, SpatialDropout1D, BatchNormalization, Dropout
import keras
from razdel import tokenize
import glob
import random
import numpy as np
from collections import defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
# %matplotlib inline


WIN_SIZE = 1000 #размер окна
WIN_STEP = 100 #шаг

# %% [markdown]
# Воспользуемся новым методом для нас загрузки датасета, описанным в официальной документации **Keras**. Данный метод позволяет избежать повторной загрузки, если данные были раньше скачаны. Метод возвращает путь к папке с датасетом.

# %%
data_path = keras.utils.get_file(
    "russian_literature.zip",
    "https://storage.yandexcloud.net/academy.ai/russian_literature.zip"
)

# %% [markdown]
# Разархивируем датасета во временную папку *dataset:*

# %%
# !unzip -qo "{data_path}" -d ./dataset
# Out:
# error:  cannot create ./dataset/poems/Blok/╨б╤В╨╕╤Е╨╛╤В╨▓╨╛╤А╨╡╨╜╨╕╤П 1897-1903 ╨│╨│, ╨╜╨╡ ╨▓╨╛╤И╨╡╨┤╤И╨╕╨╡ ╨▓ ╨╛╤Б╨╜╨╛╨▓╨╜╨╛╨╡ ╤Б╨╛╨▒╤А╨░╨╜╨╕╨╡.txt
#         File name too long
# error:  cannot create ./dataset/prose/Gogol/╨Я╨╛╨▓╨╡╤Б╤В╤М ╨╛ ╤В╨╛╨╝, ╨║╨░╨║ ╨┐╨╛╤Б╤Б╨╛╤А╨╕╨╗╤Б╤П ╨Ш╨▓╨░╨╜ ╨Ш╨▓╨░╨╜╨╛╨▓╨╕╤З ╤Б ╨Ш╨▓╨░╨╜╨╛╨╝ ╨Э╨╕╨║╨╕╤Д╨╛╤А╨╛╨▓╨╕╤З╨╡╨╝.txt
#         File name too long
# error:  cannot create ./dataset/publicism/Tolstoy/╨Ф╨╛╨║╨╗╨░╨┤, ╨┐╤А╨╕╨│╨╛╤В╨╛╨▓╨╗╨╡╨╜╨╜╤Л╨╣ ╨┤╨╗╤П ╨║╨╛╨╜╨│╤А╨╡╤Б╤Б╨░ ╨╛ ╨╝╨╕╤А╨╡ ╨▓ ╨б╤В╨╛╨║╨│╨╛╨╗╤М╨╝╨╡.txt
#         File name too long
# error:  cannot create ./dataset/publicism/Tolstoy/╨Я╨╛╤З╨╡╨╝╤Г ╤Е╤А╨╕╤Б╤В╨╕╨░╨╜╤Б╨║╨╕╨╡ ╨╜╨░╤А╨╛╨┤╤Л ╨▓╨╛╨╛╨▒╤Й╨╡ ╨╕ ╨▓ ╨╛╤Б╨╛╨▒╨╡╨╜╨╜╨╛╤Б╤В╨╕ ╤А╤Г╤Б╤Б╨║╨╕╨╣ ╨╜╨░╤Е╨╛╨┤╤П╤В╤Б╤П ╤В╨╡╨┐╨╡╤А╤М ╨▓ ╨▒╨╡╨┤╤Б╤В╨▓╨╡╨╜╨╜╨╛╨╝ ╨┐╨╛╨╗╨╛╨╢╨╡╨╜╨╕╨╕.txt
#         File name too long

# %% [markdown]
# Отберем для обучения 12 писателей:

# %%
CLASS_LIST=["Dostoevsky", "Tolstoy", "Turgenev", "Chekhov", "Lermontov", "Blok", "Pushkin", "Gogol", "Gorky", "Herzen", "Bryusov", "Nekrasov" ]

# %% [markdown]
# Следующий код собирает текстовые данные из файлов в структуру словаря *all_texts*, где *ключи* — это имена авторов, а *значения* — объединённые тексты всех их произведений.

# %%
all_texts = {} #собираем в словарь весь датасет

for author in CLASS_LIST:
    all_texts[author] = '' #инициализируем пустой строкой новый ключ словаря
    for path in glob.glob('./dataset/prose/{}/*.txt'.format(author)) +  glob.glob('./dataset/poems/{}/*.txt'.format(author)): #поиск файлов по шаблону
        with open(f'{path}', 'r', errors='ignore') as f: #игнорируем ошибки (например символы из другой кодировки)
            text = f.read() #загрузка содержимого файла в строку

        all_texts[author]  += ' ' + text.replace('\n', ' ') #заменяем символ перехода на новую строку пробелом

# %% [markdown]
# Далее выполним подсчёт популярности слов (токенов) в текстах из словаря *all_texts* и создадим словарь наиболее частых токенов (*word_index*), который можно использовать для векторизации текста.
#
# **Razdel** — это библиотека для токенизации русского текста (разбиения на слова и знаки препинания).
#
# Функция `razdel_tokenize(text)` принимает текст и возвращает список токенов (отдельных слов и символов).

# %%
#реализация токенизатора Razdel
def razdel_tokenize(text):
    return [token.text for token in tokenize(text)]

token_counts = defaultdict(int)
max_words = 10000 #укажем размер словаря

#подсчет частотности токенов
for text in all_texts.values():
    tokens = razdel_tokenize(text.lower())
    for token in tokens:
        token_counts[token] += 1

sorted_tokens = sorted(token_counts.items(), key=lambda x: x[1], reverse=True)[:max_words] #сортируем токены по частоте и берем top-N
word_index = {word: i+1 for i, (word, count) in enumerate(sorted_tokens)}  #+1 потому что 0 зарезервирован

# %% [markdown]
# Преобразуем тексты из словаря *all_texts* в числовые последовательности, используя ранее созданный словарь *word_index*. Каждое слово заменяется на соответствующий ему числовой индекс, а неизвестные слова (которых нет в *word_index*) заменяются на 0:

# %%
seq_train = []
for text in all_texts.values():
    tokens = razdel_tokenize(text)
    seq = [word_index.get(token, 0) for token in tokens if word_index.get(token, 0) < max_words]
    seq_train.append(seq)

# %% [markdown]
# Вычисляем общее количество слов в датасете:

# %%
total = sum(len(i) for i in seq_train)
print(f'Датасет состоит из {total} слов')
# Out:
# Датасет состоит из 7595911 слов

# %% [markdown]
# Далее будет представлена общая выборка по писателям, их доля в базе данных, среднее и медианное значение слов:

# %%
print('Общая выборка по писателям (по словам):')
mean_list = np.array([])
for author in CLASS_LIST:
    cls = CLASS_LIST.index(author)
    print(f'{author} - {len(seq_train[cls])} слов, доля в общей базе: {len(seq_train[cls]) / total * 100 :.2f}%')
    mean_list = np.append(mean_list, len(seq_train[cls])) #собирает данные о длинах текстов для последующей балансировки датасета

print('Среднее значение слов: ', np.round(mean_list.mean()))
print('Медианное значение слов: ', np.median(mean_list))
# Out:
# Общая выборка по писателям (по словам):
# Dostoevsky - 2256310 слов, доля в общей базе: 29.70%
# Tolstoy - 1860480 слов, доля в общей базе: 24.49%
# Turgenev - 474895 слов, доля в общей базе: 6.25%
# Chekhov - 376423 слов, доля в общей базе: 4.96%
# Lermontov - 70913 слов, доля в общей базе: 0.93%
# Blok - 117789 слов, доля в общей базе: 1.55%
# Pushkin - 271930 слов, доля в общей базе: 3.58%
# Gogol - 433091 слов, доля в общей базе: 5.70%
# Gorky - 888666 слов, доля в общей базе: 11.70%
# Herzen - 241463 слов, доля в общей базе: 3.18%
# Bryusov - 531976 слов, доля в общей базе: 7.00%
# Nekrasov - 71975 слов, доля в общей базе: 0.95%
# Среднее значение слов:  632993.0
# Медианное значение слов:  404757.0

# %% [markdown]
# Далее необходимо выполнить сбалансированную выборку и из оставшихся писателей отобрать 5 случайным образом:

# %%
#сбалансированная выборка
median = int(np.median(mean_list))  #зафиксировали медианное значение
seq_train_balance = []
CLASS_LIST_BALANCE = []
for author in CLASS_LIST:
    cls = CLASS_LIST.index(author)
    if len(seq_train[cls]) > median * 0.6:
        seq_train_balance.append(seq_train[cls][:median])
        CLASS_LIST_BALANCE.append(author)

#cлучайный выбор 5 писателей из сбалансированного списка
selected_authors = random.sample(CLASS_LIST_BALANCE, 5)
selected_seq_train_balance = [seq_train_balance[CLASS_LIST_BALANCE.index(author)] for author in selected_authors]

# %% [markdown]
# Далее будет представлена сбалансированная выборка по писателям, их доля в общей базе данных, среднее и медианное значение слов:

# %%
total = sum(len(i) for i in selected_seq_train_balance)
print('Сбалансированная выборка по писателям (по словам):')
mean_list_balance = np.array([])
for author, seq in zip(selected_authors, selected_seq_train_balance):
    print(f'{author} - {len(seq)} слов, доля в общей базе: {len(seq)/total*100 :.2f}%')
    mean_list_balance = np.append(mean_list_balance, len(seq))

print('Среднее значение слов: ', np.round(mean_list_balance.mean()))
print('Медианное значение слов: ', np.median(mean_list_balance))
# Out:
# Сбалансированная выборка по писателям (по словам):
# Bryusov - 404757 слов, доля в общей базе: 21.73%
# Gogol - 404757 слов, доля в общей базе: 21.73%
# Chekhov - 376423 слов, доля в общей базе: 20.21%
# Turgenev - 404757 слов, доля в общей базе: 21.73%
# Pushkin - 271930 слов, доля в общей базе: 14.60%
# Среднее значение слов:  372525.0
# Медианное значение слов:  404757.0

# %% [markdown]
# Затем создадим круговую диаграмму, в которой будут представлены 5 писателей и их доля текста в общей базе данных:

# %%
#построение диаграммы
fig, ax = plt.subplots()
ax.pie([len(i) for i in selected_seq_train_balance],
       labels=selected_authors,
       pctdistance=1.2,
       labeldistance=1.4,
       autopct='%1.2f%%')
plt.show()

# %% [markdown]
# Далее реализуем 2 функции, а именно: **seq_split**, которая отвечает за разбиение последовательности чисел на небольшие "окна" фиксированной длины и **seq_vectorize**, которая осуществляет подготовку данных для нейросетей с разделением на обучение/валидацию/тест:

# %%
def seq_split(sequence, win_size, step):
    return [sequence[i:i + win_size] for i in range(0, len(sequence) - win_size + 1, step)]

def seq_vectorize(seq_list, test_split, val_split, class_list, win_size, step):
    x_train, y_train = [], []
    x_val, y_val = [], []
    x_test, y_test = [], []

    #обрабатываем каждую последовательность
    for class_idx, seq in enumerate(seq_list):
        #вычисляем границы разделения последовательности
        total_len = len(seq)
        val_end = int(total_len * (1 - test_split - val_split))
        test_end = int(total_len * (1 - test_split))

        #разбиваем последовательность на окна для каждой части
        train_windows = seq_split(seq[:val_end], win_size, step)
        val_windows = seq_split(seq[val_end:test_end], win_size, step)
        test_windows = seq_split(seq[test_end:], win_size, step)

        #добавляем окна в соответствующие списки
        x_train += train_windows
        x_val += val_windows
        x_test += test_windows

        #создаем one-hot метки и добавляем их в соответствующие списки
        #количество меток равно количеству окон
        y_train += [keras.utils.to_categorical(class_idx, len(class_list))] * len(train_windows)
        y_val += [keras.utils.to_categorical(class_idx, len(class_list))] * len(val_windows)
        y_test += [keras.utils.to_categorical(class_idx, len(class_list))] * len(test_windows)

    #преобразуем списки в numpy массивы и возвращаем результат
    return (np.array(x_train), np.array(y_train),
            np.array(x_val), np.array(y_val),
            np.array(x_test), np.array(y_test))

# %% [markdown]
# Выполним финальную подготовку данных для обучения нейросетевой модели, преобразуя тексты в числовой формат и разделяя их на обучающую, валидационную и тестовую выборки:

# %%
x_train, y_train, x_val, y_val, x_test, y_test = seq_vectorize(
    selected_seq_train_balance, #используем сбалансированную выборку из 5 авторов
    test_split=0.1,
    val_split=0.1,
    class_list=selected_authors, #передаём только выбранных 5 авторов
    win_size=WIN_SIZE,
    step=WIN_STEP
)

# %% [markdown]
# Убедимся в корректности распределения данных:

# %%
print(f'Форма входных данных для обучающей выборки: {x_train.shape}')
print(f'Форма выходных данных (меток) для обучающей выборки: {y_train.shape}')
# Out:
# Форма входных данных для обучающей выборки: (14855, 1000)
# Форма выходных данных (меток) для обучающей выборки: (14855, 5)

# %%
print(f'Форма входных данных для тестовой выборки: {x_test.shape}')
print(f'Форма выходных данных (меток) для тестовой выборки: {y_test.shape}')
# Out:
# Форма входных данных для тестовой выборки: (1814, 1000)
# Форма выходных данных (меток) для тестовой выборки: (1814, 5)

# %%
print(f'Форма входных данных для валидационной выборки: {x_val.shape}')
print(f'Форма выходных данных (меток) для валидационной выборки: {y_val.shape}')
# Out:
# Форма входных данных для валидационной выборки: (1814, 1000)
# Форма выходных данных (меток) для валидационной выборки: (1814, 5)

# %% [markdown]
# Напишем 2 функции, а именно: **show_plot**, которая отвечает за отрисовку графиков точности и ошибки, и **show_confusion_matrix**, которая выводит матрицу ошибок и предсказанные значения:

# %%
def show_plot(history):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 5))
    fig.suptitle('График процесса обучения модели')
    ax1.plot(history.history['accuracy'],
               label='График точности на обучающей выборке')
    ax1.plot(history.history['val_accuracy'],
               label='График точности на проверочной выборке')
    ax1.xaxis.get_major_locator().set_params(integer=True) #на оси х показываем целые числа
    ax1.set_xlabel('Эпоха обучения')
    ax1.set_ylabel('График точности')
    ax1.legend()

    ax2.plot(history.history['loss'],
               label='Ошибка на обучающей выборке')
    ax2.plot(history.history['val_loss'],
               label='Ошибка на проверочной выборке')
    ax2.xaxis.get_major_locator().set_params(integer=True)
    ax2.set_xlabel('Эпоха обучения')
    ax2.set_ylabel('Ошибка')
    ax2.legend()
    plt.show()


def show_confusion_matrix(y_true, y_pred, class_labels):
    #матрица ошибок
    cm = confusion_matrix(np.argmax(y_true, axis=1),
                          np.argmax(y_pred, axis=1),
                          normalize='true')

    cm = np.around(cm, 3) #округление значений матрицы ошибок

    #отрисовка матрицы ошибок
    fig, ax = plt.subplots(figsize=(10, 10))
    ax.set_title(f'Матрица ошибок', fontsize=18)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_labels)
    disp.plot(ax=ax)
    plt.gca().images[-1].colorbar.remove()  #убираем ненужную цветовую шкалу
    plt.xlabel('Предсказанные классы', fontsize=16)
    plt.ylabel('Верные классы', fontsize=16)
    fig.autofmt_xdate(rotation=45) #наклон меток горизонтальной оси
    plt.show()


    #средняя точность распознавания определяется как среднее диагональных элементов матрицы ошибок
    print('\nСредняя точность распознавания: {:3.0f}%'.format(100. * cm.diagonal().mean()))

# %% [markdown]
# Загрузим предобученную модель, инициализируем матрицу эмбеддингов и заполним матрицы векторами слов:
#
# `hudlit_12B_500K_300d_100q` — это **GloVe-эмбединги** обученные на 145ГБ художественной литературы. Архив с текстами взят из проекта **RUSSE** и использует оригинальную реализацию GloVe на C, обернутую в удобный Python-интерфейс.
#
# Размер словаря `hudlit_12B_500K_300d_100q` — 500 000 записей, он покрывает 98% слов в художественных текстах. Оптимальная размерность векторов — 300. Таблица 500 000 × 300 из float-чисел занимает 578МБ, размер архива с весами `hudlit_12B_500K_300d_100q` в 12 раз меньше (48МБ). И это благодаря **квантизации**.

# %%
navec = Navec.load('navec_hudlit_v1_12B_500K_300d_100q.tar')
embedding_matrix = np.zeros((max_words, 300))
for word, i in word_index.items():
    if i < max_words:
        embedding_vector = navec.get(word)
        if embedding_vector is not None: #слова, которых нет в Navec (или с индексом >= max_words), получают нулевой вектор
            embedding_matrix[i] = embedding_vector

# %% [markdown]
# Так как мы используем предварительно сформированные векторные представления, то это накладывает ограничения на размерность входного слоя `Embedding` нашей модели (смотрим по имени файла navec_hudlit_v1_12B_500K_**300d**_100q.tar):
#
# Слой Embedding в качестве весов использует - двумерную матрицу с вещественными числами, каждый `i`-й элемент которой — это вектор, связанный с `i`-м словом в индексе. Все довольно просто. Загрузим подготовленную матрицу в слой `Embedding` с помощью параметра `weights`.
#
# Мы также заморозили слой `Embedding` (присвоив атрибуту `trainable` значение
# `False`). Когда мы знакомились с особенностями применения предварительно обученных сверточных нейронных сетей мы говорили, что если в модели имеются уже обученные части (как наш слой Embedding) и части, инициализированные случайными значениями (как наш классификатор), то обученные части не должны изменяться в ходе обучения, чтобы не потерять свои знания.
#
# Большие изменения градиента, вызванные случайными начальными значениями
# в необученных слоях, могут оказать разрушительное влияние на обученные слои.

# %%
model = Sequential()
model.add(Embedding(max_words, 300, input_length=WIN_SIZE, weights=[embedding_matrix]))
model.add(BatchNormalization())
Dense(64, activation='relu')
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(GlobalAveragePooling1D())
model.add(Dense(len(selected_authors), activation='softmax'))

model.layers[0].trainable = False
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %% [markdown]
# Выполним разделение данных (*train_test_split*), настроим 3 callbacks, а именно: **ModelCheckpoint**, **EarlyStopping** и **ReduceLROnPlateau**:

# %%
x_train_final, x_val_final, y_train_final, y_val_final = train_test_split(
    x_train,
    y_train,
    test_size=0.1,
    random_state=42,
    stratify=y_train
)

checkpoint = ModelCheckpoint(
    'best_model.keras',
    monitor='val_accuracy',
    verbose=0,
    save_best_only=True,
    mode='max'
)

early_stopping = EarlyStopping(
    monitor='val_accuracy',
    patience=5,
    restore_best_weights=True,
    verbose=0
)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3)

# %% [markdown]
# Выполним компиляцию модели и приступим к её обучению:

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(
    x_train_final, y_train_final,
    epochs=50,
    batch_size=64,
    validation_data=(x_val_final, y_val_final),
    callbacks=[checkpoint, early_stopping, reduce_lr],
    verbose=1
)
# Out:
# Epoch 1/50
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 218s 1s/step - accuracy: 0.4610 - loss: 1.4330 - val_accuracy: 0.6447 - val_loss: 1.2416 - learning_rate: 0.0010
# Epoch 2/50
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 214s 1s/step - accuracy: 0.7301 - loss: 0.9558 - val_accuracy: 0.7907 - val_loss: 0.7776 - learning_rate: 0.0010
# Epoch 3/50
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 213s 1s/step - accuracy: 0.8054 - loss: 0.7123 - val_accuracy: 0.8425 - val_loss: 0.5760 - learning_rate: 0.0010
# Epoch 4/50
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 212s 1s/step - accuracy: 0.8422 - loss: 0.5735 - val_accuracy: 0.8641 - val_loss: 0.4788 - learning_rate: 0.0010
# Epoch 5/50
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 214s 1s/step - accuracy: 0.8627 - loss: 0.4862 - val_accuracy: 0.8795 - val_loss: 0.4152 - learning_rate: 0.0010
# Epoch 6/50
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 259s 1s/step - accuracy: 0.8768 - loss: 0.4327 - val_accuracy: 0.8964 - val_loss: 0.3664 - learning_rate: 0.0010
# Epoch 7/50
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 267s 1s/step - accuracy: 0.8904 - loss: 0.3790 - val_accuracy: 0.9092 - val_loss: 0.3286 - learning_rate: 0.0010
# Epoch 8/50
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 256s 1s/step - accuracy: 0.8919 - loss: 0.3578 - val_accuracy: 0.9179 - val_loss: 0.2989 - learning_rate: 0.0010
# Epoch 9/50
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 264s 1s/step - accuracy: 0.9013 - loss: 0.3303 - val_accuracy: 0.9206 - val_loss: 0.2780 - learning_rate: 0.0010
# Epoch 10/50
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 263s 1s/step - accuracy: 0.9054 - loss: 0.3074 - val_accuracy: 0.9253 - val_loss: 0.2604 - learning_rate: 0.0010
# Epoch 11/50
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 261s 1s/step - accuracy: 0.9149 - loss: 0.2872 - val_accuracy: 0.9367 - val_loss: 0.2408 - learning_rate: 0.0010
# Epoch 12/50
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 263s 1s/step - accuracy: 0.9156 - loss: 0.2674 - val_accuracy: 0.9367 - val_loss: 0.2275 - learning_rate: 0.0010
# Epoch 13/50
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 211s 1s/step - accuracy: 0.9212 - loss: 0.2611 - val_accuracy: 0.9394 - val_loss: 0.2190 - learning_rate: 0.0010
# Epoch 14/50
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 263s 1s/step - accuracy: 0.9249 - loss: 0.2431 - val_accuracy: 0.9495 - val_loss: 0.2035 - learning_rate: 0.0010
# Epoch 15/50
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 261s 1s/step - accuracy: 0.9236 - loss: 0.2408 - val_accuracy: 0.9435 - val_loss: 0.1960 - learning_rate: 0.0010
# Epoch 16/50
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 264s 1s/step - accuracy: 0.9261 - loss: 0.2369 - val_accuracy: 0.9462 - val_loss: 0.1936 - learning_rate: 0.0010
# Epoch 17/50
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 262s 1s/step - accuracy: 0.9259 - loss: 0.2307 - val_accuracy: 0.9502 - val_loss: 0.1804 - learning_rate: 0.0010
# Epoch 18/50
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 259s 1s/step - accuracy: 0.9326 - loss: 0.2179 - val_accuracy: 0.9515 - val_loss: 0.1711 - learning_rate: 0.0010
# Epoch 19/50
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 210s 1s/step - accuracy: 0.9289 - loss: 0.2177 - val_accuracy: 0.9603 - val_loss: 0.1632 - learning_rate: 0.0010
# Epoch 20/50
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 263s 1s/step - accuracy: 0.9307 - loss: 0.2101 - val_accuracy: 0.9495 - val_loss: 0.1726 - learning_rate: 0.0010
# Epoch 21/50
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 264s 1s/step - accuracy: 0.9310 - loss: 0.2052 - val_accuracy: 0.9542 - val_loss: 0.1611 - learning_rate: 0.0010
# Epoch 22/50
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 260s 1s/step - accuracy: 0.9346 - loss: 0.2010 - val_accuracy: 0.9569 - val_loss: 0.1522 - learning_rate: 0.0010
# Epoch 23/50
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 265s 1s/step - accuracy: 0.9306 - loss: 0.2014 - val_accuracy: 0.9603 - val_loss: 0.1454 - learning_rate: 0.0010
# Epoch 24/50
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 262s 1s/step - accuracy: 0.9360 - loss: 0.1937 - val_accuracy: 0.9630 - val_loss: 0.1411 - learning_rate: 0.0010
# Epoch 25/50
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 215s 1s/step - accuracy: 0.9299 - loss: 0.1998 - val_accuracy: 0.9616 - val_loss: 0.1386 - learning_rate: 0.0010
# Epoch 26/50
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 260s 1s/step - accuracy: 0.9340 - loss: 0.1902 - val_accuracy: 0.9637 - val_loss: 0.1380 - learning_rate: 0.0010
# Epoch 27/50
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 260s 1s/step - accuracy: 0.9384 - loss: 0.1810 - val_accuracy: 0.9670 - val_loss: 0.1313 - learning_rate: 0.0010
# Epoch 28/50
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 262s 1s/step - accuracy: 0.9397 - loss: 0.1810 - val_accuracy: 0.9643 - val_loss: 0.1268 - learning_rate: 0.0010
# Epoch 29/50
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 210s 1s/step - accuracy: 0.9380 - loss: 0.1826 - val_accuracy: 0.9670 - val_loss: 0.1269 - learning_rate: 0.0010
# Epoch 30/50
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 212s 1s/step - accuracy: 0.9406 - loss: 0.1828 - val_accuracy: 0.9697 - val_loss: 0.1220 - learning_rate: 0.0010
# Epoch 31/50
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 264s 1s/step - accuracy: 0.9431 - loss: 0.1736 - val_accuracy: 0.9690 - val_loss: 0.1207 - learning_rate: 0.0010
# Epoch 32/50
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 261s 1s/step - accuracy: 0.9407 - loss: 0.1758 - val_accuracy: 0.9677 - val_loss: 0.1199 - learning_rate: 0.0010
# Epoch 33/50
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 262s 1s/step - accuracy: 0.9435 - loss: 0.1708 - val_accuracy: 0.9697 - val_loss: 0.1164 - learning_rate: 0.0010
# Epoch 34/50
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 260s 1s/step - accuracy: 0.9432 - loss: 0.1669 - val_accuracy: 0.9690 - val_loss: 0.1152 - learning_rate: 0.0010
# Epoch 35/50
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 230s 1s/step - accuracy: 0.9467 - loss: 0.1644 - val_accuracy: 0.9704 - val_loss: 0.1140 - learning_rate: 0.0010
# Epoch 36/50
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 209s 999ms/step - accuracy: 0.9435 - loss: 0.1626 - val_accuracy: 0.9670 - val_loss: 0.1081 - learning_rate: 0.0010
# Epoch 37/50
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 268s 1s/step - accuracy: 0.9447 - loss: 0.1643 - val_accuracy: 0.9751 - val_loss: 0.1061 - learning_rate: 0.0010
# Epoch 38/50
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 209s 999ms/step - accuracy: 0.9400 - loss: 0.1744 - val_accuracy: 0.9690 - val_loss: 0.1054 - learning_rate: 0.0010
# Epoch 39/50
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 209s 999ms/step - accuracy: 0.9414 - loss: 0.1644 - val_accuracy: 0.9717 - val_loss: 0.1022 - learning_rate: 0.0010
# Epoch 40/50
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 268s 1s/step - accuracy: 0.9481 - loss: 0.1578 - val_accuracy: 0.9711 - val_loss: 0.1028 - learning_rate: 0.0010
# Epoch 41/50
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 255s 995ms/step - accuracy: 0.9433 - loss: 0.1645 - val_accuracy: 0.9731 - val_loss: 0.0983 - learning_rate: 0.0010
# Epoch 42/50
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 263s 1s/step - accuracy: 0.9440 - loss: 0.1641 - val_accuracy: 0.9738 - val_loss: 0.0975 - learning_rate: 0.0010

# %% [markdown]
# Воспользуемся функцией **show_plot**:

# %%
show_plot(history)

# %% [markdown]
# Загружаем лучшую сохранённую версию, тестируем её на данных, которые модель не видела при обучении, визуализируем ошибки для анализа:

# %%
best_model = load_model('best_model.keras')

y_pred = best_model.predict(x_test)
show_confusion_matrix(y_test, y_pred, selected_authors)
# Out:
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step
# Средняя точность распознавания:  90%
